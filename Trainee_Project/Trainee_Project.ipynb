# %%
import pandas as pd

# %%
a=pd.read_csv(r"C:\Users\DurgaprasadChou\Downloads\trainee.csv")
print(a.head())
df = pd.DataFrame(a)
result = a.dtypes
print(result)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# ...

# %%
print(df)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
print("datatype before getting changed")
print(df["Pclass"])
print()
print()
print()
df["Pclass"] = df["Pclass"].astype("float")
print("datatype after getting changed")
print(df["Pclass"])
# Out:
# datatype before getting changed
# 0      3.0
# 1      1.0
# 2      3.0
# 3      1.0
# 4      3.0
#       ...
# 886    2.0
# 887    1.0
# 888    3.0
# 889    1.0
# 890    3.0
# Name: Pclass, Length: 891, dtype: float64
#
#
#
# datatype after getting changed
# 0      3.0
# 1      1.0
# 2      3.0
# 3      1.0
# 4      3.0
#       ...
# 886    2.0
# 887    1.0
# 888    3.0
# 889    1.0
# 890    3.0
# Name: Pclass, Length: 891, dtype: float64

# %%
print("datatype before getting changed")
print(df["Sex"])
print()
print()
print()
df["Sex"] = df["Sex"].astype("int64",errors='ignore')
print("datatype after getting changed")
print(df["Sex"])
# Out:
# datatype before getting changed
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
#         ...
# 886      male
# 887    female
# 888    female
# 889      male
# 890      male
# Name: Sex, Length: 891, dtype: object
#
#
#
# datatype after getting changed
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
#         ...
# 886      male
# 887    female
# 888    female
# 889      male
# 890      male
# Name: Sex, Length: 891, dtype: object

# %%
df1 = df.reindex(columns=['Name','PassengerID','Survived','Pclass','Sex','Age','SibSp','Parch','Ticket','Fare','Cabin','Embarked'])
print(df1)
# Out:
#                                                   Name  PassengerID  Survived  \
# 0                              Braund, Mr. Owen Harris          NaN         0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...          NaN         1
# 2                               Heikkinen, Miss. Laina          NaN         1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)          NaN         1
# 4                             Allen, Mr. William Henry          NaN         0
# ..                                                 ...          ...       ...
# 886                              Montvila, Rev. Juozas          NaN         0
# 887                       Graham, Miss. Margaret Edith          NaN         1
# 888           Johnston, Miss. Catherine Helen "Carrie"          NaN         0
# 889                              Behr, Mr. Karl Howell          NaN         1
# 890                                Dooley, Mr. Patrick          NaN         0
#
# ...

# %%
b = int(input('Enter the Number of a row : '))
skip_func = lambda x: x%b != 0
df2 = pd.read_csv(r"C:\Users\DurgaprasadChou\Downloads\trainee.csv",skiprows = skip_func)

print(df2.to_string())
# Out:
# Enter the Number of a row : 5
#      PassengerId  Survived  Pclass                                                      Name     Sex    Age  SibSp  Parch              Ticket      Fare        Cabin Embarked
# 0              5         0       3                                  Allen, Mr. William Henry    male  35.00      0      0              373450    8.0500          NaN        S
# 1             10         1       2                       Nasser, Mrs. Nicholas (Adele Achem)  female  14.00      1      0              237736   30.0708          NaN        C
# 2             15         0       3                      Vestrom, Miss. Hulda Amanda Adolfina  female  14.00      0      0              350406    7.8542          NaN        S
# 3             20         1       3                                   Masselmani, Mrs. Fatima  female    NaN      0      0                2649    7.2250          NaN        C
# ...

# %%
xls = pd.read_excel(r"C:\Users\DurgaprasadChou\Downloads\KPMG_VI_New_raw_data_update_final.xlsx",'Transactions')

print(xls)
# Out:
#        transaction_id  product_id  customer_id transaction_date  online_order  \
# 0                 140          11          462       2017-01-01           0.0
# 1                 517          77          311       2017-01-01           1.0
# 2                 561          65         2298       2017-01-01           0.0
# 3                1293          67         1931       2017-01-01           1.0
# 4                1403           0         2891       2017-01-01           1.0
# ...               ...         ...          ...              ...           ...
# 19995           17394          20          933       2017-12-30           0.0
# 19996           18609          27         2372       2017-12-30           0.0
# 19997           19346           4          543       2017-12-30           0.0
# 19998           19907          41         1721       2017-12-30           0.0
# 19999           19959           4         1787       2017-12-30           0.0
#
# ...

# %%
#Remove columns
del df["Sex"]
print(df.head())
print('We can see "Sex" column is missing from the dataset')
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0     3.0
# 1            2         1     1.0
# 2            3         1     3.0
# 3            4         1     1.0
# 4            5         0     3.0
#
#                                                 Name   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                             Heikkinen, Miss. Laina  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 4                           Allen, Mr. William Henry  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S
# We can see "Sex" column is missing from the dataset

# %%
#Add new columns
df.insert(1, "Species", 'Human Being')
print(df)
# Out:
#      PassengerId      Species  Survived  Pclass  \
# 0              1  Human Being         0     3.0
# 1              2  Human Being         1     1.0
# 2              3  Human Being         1     3.0
# 3              4  Human Being         1     1.0
# 4              5  Human Being         0     3.0
# ..           ...          ...       ...     ...
# 886          887  Human Being         0     2.0
# 887          888  Human Being         1     1.0
# 888          889  Human Being         0     3.0
# 889          890  Human Being         1     1.0
# 890          891  Human Being         0     3.0
#
#                                                   Name   Age  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris  22.0      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                               Heikkinen, Miss. Laina  26.0      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# ...

# %%
#Filtering Data based on Singular column.
a1= a.loc[a['Age'] > 26]
print(a1)
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1     1.0
# 3              4         1     1.0
# 4              5         0     3.0
# 6              7         0     1.0
# 8              9         1     3.0
# ..           ...       ...     ...
# 881          882         0     3.0
# 883          884         0     2.0
# 885          886         0     3.0
# 886          887         0     2.0
# 890          891         0     3.0
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#Filtering Data based on based on a number range.
a.loc[(a['Age'] >= 25) & (a['Age'] <= 50)]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1     1.0
# 2              3         1     3.0
# 3              4         1     1.0
# 4              5         0     3.0
# 8              9         1     3.0
# ..           ...       ...     ...
# 884          885         0     3.0
# 885          886         0     3.0
# 886          887         0     2.0
# 889          890         1     1.0
# 890          891         0     3.0
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
asplit=pd.read_csv(r"C:\Users\DurgaprasadChou\Downloads\icons.csv")
print(asplit)

asplit[['First leter', 'Last Name']] = asplit.Name.str.split(" ", expand = True)
print(asplit)
# Out:
#         Name
# 0    V Kohli
# 1  C Ronaldo
# 2   MS Dhoni
# 3    L Messi
#         Name First leter Last Name
# 0    V Kohli           V     Kohli
# 1  C Ronaldo           C   Ronaldo
# 2   MS Dhoni          MS     Dhoni
# 3    L Messi           L     Messi

# %%
i1 = pd.read_csv(r"C:\Users\DurgaprasadChou\Downloads\Icon1.csv")
print(i1.head())
print()
print()
i2 = pd.read_csv(r"C:\Users\DurgaprasadChou\Downloads\Icon2.csv")
print(i2)

print('Lets perform Concatination')
print()
print()

ijoin = pd.concat([i1,i2], ignore_index=True)
print(ijoin)
# Out:
#     Name     Sport
# 0  Dhoni   Cricket
# 1  Messi  Football
#
#
#         Name     Sport
# 0    V Kohli   Cricket
# 1  C Ronaldo  Football
# Lets perform Concatination
#
#
#         Name     Sport
# 0      Dhoni   Cricket
# 1      Messi  Football
# 2    V Kohli   Cricket
# 3  C Ronaldo  Football

# %%
iinner = pd.merge(i1, i2, on='Name', how='inner')
print(iinner)
# Out:
# Empty DataFrame
# Columns: [Name, Sport_x, Sport_y]
# Index: []

# %%
irouter = pd.merge(i1, i2, on='Name', how='right')
print(irouter)
# Out:
#         Name Sport_x   Sport_y
# 0    V Kohli     NaN   Cricket
# 1  C Ronaldo     NaN  Football

# %%
ilouter = pd.merge(i1, i2, on='Name', how='left')
print(ilouter)
# Out:
#     Name   Sport_x Sport_y
# 0  Dhoni   Cricket     NaN
# 1  Messi  Football     NaN

# %%
iouter = pd.merge(i1, i2, on='Name', how='outer')
print(iouter)
# Out:
#         Name   Sport_x   Sport_y
# 0      Dhoni   Cricket       NaN
# 1      Messi  Football       NaN
# 2    V Kohli       NaN   Cricket
# 3  C Ronaldo       NaN  Football

# %%
a.rename(columns = {'Name':'NAME','Sex':'SEX','Age':"AGE"}, inplace = True)
print(a)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0     3.0
# 1              2         1     1.0
# 2              3         1     3.0
# 3              4         1     1.0
# 4              5         0     3.0
# ..           ...       ...     ...
# 886          887         0     2.0
# 887          888         1     1.0
# 888          889         0     3.0
# 889          890         1     1.0
# 890          891         0     3.0
#
#                                                   NAME     SEX   AGE  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...
